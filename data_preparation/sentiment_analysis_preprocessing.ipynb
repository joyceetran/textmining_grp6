# %%
import re
import os
import pandas as pd
import nltk


# ── Config ──────────────────────────────────────────────────────────
CLEAN_MDA_FILEPATH = "../Data Preparation/mda_shared_preprocessed.csv"    
CLEAN_MDA   =      pd.read_csv(CLEAN_MDA_FILEPATH)
