# %%
import re
import os
import pandas as pd
import nltk


# ── Config ──────────────────────────────────────────────────────────
CLEAN_MDA_FILEPATH = "../Data Preparation/Processed_MDA/mda_shared_preprocessed.csv"    
CLEAN_MDA   =      pd.read_csv(CLEAN_MDA_FILEPATH)

# %%
CLEAN_MDA.head(20)
# Out:
#                            doc_id   company_name filing_type filing_date  \
# 0   1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds        10-Q  2020-01-28
# 1   1-800-PetMeds_10-K_2020-05-26  1-800-PetMeds        10-K  2020-05-26
# 2   1-800-PetMeds_10-Q_2020-08-03  1-800-PetMeds        10-Q  2020-08-03
# 3   1-800-PetMeds_10-Q_2020-11-03  1-800-PetMeds        10-Q  2020-11-03
# 4   1-800-PetMeds_10-Q_2021-01-26  1-800-PetMeds        10-Q  2021-01-26
# 5   1-800-PetMeds_10-K_2021-05-25  1-800-PetMeds        10-K  2021-05-25
# 6   1-800-PetMeds_10-K_2022-05-24  1-800-PetMeds        10-K  2022-05-24
# 7   1-800-PetMeds_10-K_2023-05-23  1-800-PetMeds        10-K  2023-05-23
# 8   1-800-PetMeds_10-Q_2023-08-02  1-800-PetMeds        10-Q  2023-08-02
# 9   1-800-PetMeds_10-Q_2023-10-31  1-800-PetMeds        10-Q  2023-10-31
# 10  1-800-PetMeds_10-Q_2024-04-15  1-800-PetMeds        10-Q  2024-04-15
# 11  1-800-PetMeds_10-K_2024-06-14  1-800-PetMeds        10-K  2024-06-14
# ...
