# %%
# !pip install pandas

import pandas as pd 
hello = pd.read_parquet("./labeled_sentiment.parquet")

hello
# Out:
# ...
#                                doc_id        company quarter  \
# 0       1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# 1       1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# 2       1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# 3       1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# 4       1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# ...                               ...            ...     ...
# 452385   reAlpha_Tech_10-Q_2025-11-12   reAlpha_Tech      Q4
# 452386   reAlpha_Tech_10-Q_2025-11-12   reAlpha_Tech      Q4
# 452387   reAlpha_Tech_10-Q_2025-11-12   reAlpha_Tech      Q4
# 452388   reAlpha_Tech_10-Q_2025-11-12   reAlpha_Tech      Q4
# 452389   reAlpha_Tech_10-Q_2025-11-12   reAlpha_Tech      Q4
#
#                                                  sentence    label       pos  \
# 0       presently the companys product line includes a...  neutral  0.000687
# ...

# %%
hello['label'].value_counts()
# Out:
# label
# neutral     377900
# positive     38319
# negative     36171
# Name: count, dtype: int64

# %%
pos_neg = hello.query("label != 'neutral'")
pos_neg.head(100)
# Out:
#                             doc_id        company quarter  \
# 18   1-800-PetMeds_10-Q_2020-01-28  1-800-PetMeds      Q1
# 32   1-800-PetMeds_10-K_2020-05-26  1-800-PetMeds      Q2
# 41   1-800-PetMeds_10-K_2020-05-26  1-800-PetMeds      Q2
# 52   1-800-PetMeds_10-Q_2020-08-03  1-800-PetMeds      Q3
# 54   1-800-PetMeds_10-Q_2020-08-03  1-800-PetMeds      Q3
# ..                             ...            ...     ...
# 629     3D_Systems_10-Q_2016-08-03     3D_Systems      Q3
# 630     3D_Systems_10-Q_2016-08-03     3D_Systems      Q3
# 636     3D_Systems_10-Q_2016-08-03     3D_Systems      Q3
# 646     3D_Systems_10-Q_2016-11-03     3D_Systems      Q4
# 648     3D_Systems_10-Q_2016-11-03     3D_Systems      Q4
#
#                                               sentence     label       pos  \
# 18   the decrease to other income for the quarter e...  negative  0.000073
# 32   due to covid- NUM consumer demand has increase...  positive  0.999299
# ...
